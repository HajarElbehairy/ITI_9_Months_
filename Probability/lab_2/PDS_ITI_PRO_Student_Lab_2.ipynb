# %% [markdown]
# # LAB 2: Probability Distributions and Statistical Data Visualization
#
# In this lab you will use python to study the following topics:
#
# - How to sample from different distributions functions.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for different distributions functions.
# - Statistical data visualization using seaborn library

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np
from scipy import stats


# matplotlib library
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # Problem 1
# a) Use the numpy function [numpy.random.normal](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to generate a standard Gaussian random variable $X$ (zero mean and unit variance).
#
# - Use histogram to plot the estimated PDF of the random variable $X$
# - Compute the true "analytical" PDF -using the equation- of $X$ . Plot the true PDF on the top of the histogram figure.
# - Calculate the sample mean and the sample variance.

# %% [markdown]
# ### True/Analytical PDF
# ![image.png](attachment:image.png)

# %% [markdown]
# ## using `numpy`

# %%
#type your code here:
# Out:
# Sample mean: 0.01589717727652419
# Sample variance: 0.9944424475117524

# %%
# my code
import numpy as np
import matplotlib.pyplot as plt


sample = np.random.normal(loc=0, scale=1, size=100_000)
sample_mean = np.mean(sample)
sample_std = np.std(sample)

print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_std}")

plt.hist(sample, bins=25, density=True,  color='blue')

x = np.linspace(-5, 5, 100)  
true_pdf =  1 / (sample_std * np.sqrt(2 * np.pi)) * np.exp(-(x - sample_mean)**2 / (2 * sample_std**2))


plt.plot(x, true_pdf, 'r-')

plt.show()
# Out:
# Sample mean: 0.005895521395956469
# Sample variance: 0.9990593426247225

# %% [markdown]
# ## using `scipy`

# %%
#type your code here:
# Out:
# Sample mean: 0.01589717727652419
# Sample variance: 0.9944424475117524

# %%
# my code
sample=stats.norm.rvs(loc=0, scale=1, size=100_000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)

print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
x=np.linspace(-5,5,100)
plt.hist(sample, bins=25, density=True,  color='blue')
plt.plot(x,stats.norm.pdf(x, 0, 1), 'r-')
plt.show()
# Out:
# Sample mean: 0.0011222699292449598
# Sample variance: 0.9910437629465277

# %% [markdown]
# - Compute the true "analytical" PDF using [scipy.stats.norm.pdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html). Plot the true PDF on the top of the histogram figure.
# - Compute the CDF using [scipy.stats.norm.cdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html), then plot it.

# %%
#type your code here:

# %%
#my code
sample=stats.norm.rvs(loc=0, scale=1, size=100000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)
pdf=stats.norm.pdf(x, 0, 1)
cdf=stats.norm.cdf(x, 0, 1)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
plt.hist(sample, bins=25, density=True,  color='blue')
plt.plot(x,pdf, 'r-')
plt.plot(x,cdf, 'g-')
plt.show()
# Out:
# Sample mean: 0.003930186627728734
# Sample variance: 0.9925644444182629

# %% [markdown]
# b) Repeat (a) for a Gaussian random variable $Y$ with $mean=3$ and $variance=4$.

# %%
#type your code here:
# Out:
# Sample mean: 2.9570133538646415
# Sample variance: 3.9437893311031664

# %%
# my code
sample=stats.norm.rvs(loc=3, scale=2, size=100_000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)

print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
x=np.linspace(-5,15,1000)
plt.hist(sample, bins=25, density=True,  color='blue')
plt.plot(x,stats.norm.pdf(x, 3, 2), 'r-')
plt.show()
# Out:
# Sample mean: 2.994947282382253
# Sample variance: 3.9791856646830728

# %%
#type your code here:

# %%
#my code
sample=stats.norm.rvs(loc=3, scale=2, size=100000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)
pdf=stats.norm.pdf(x, 3, 2)
cdf=stats.norm.cdf(x, 3, 2)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
plt.hist(sample, bins=25, density=True,  color='blue')
plt.plot(x,pdf, 'r-')
plt.plot(x,cdf, 'g-')
plt.show()
# Out:
# Sample mean: 2.996772830797802
# Sample variance: 3.993742022883992

# %% [markdown]
# C) Repeat (a) for an exponential random variable with $\lambda = 1$ using [numpy.random.exponential](https://numpy.org/doc/stable/reference/random/generated/numpy.random.exponential.html), and [scipy.stats.expon](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html#scipy.stats.expon)

# %%
#type your code here:
# Out:
# Sample mean: 1.0011220637243747
# Sample variance: 1.002224188207073

# %%
#my code
sample=stats.expon.rvs(scale=1, size=1000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)
pdf=stats.expon.pdf(x, scale=1)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
plt.hist(sample, bins=15, density=True,  color='blue')
plt.plot(x,pdf, 'r-')
plt.show()
# Out:
# Sample mean: 0.9965942963599448
# Sample variance: 1.1066865442478953

# %%
#type your code here:

# %%
#my code
sample=stats.expon.rvs(scale=1, size=1000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)
pdf=stats.expon.pdf(x, scale=1)
cdf=stats.expon.cdf(x, scale=1)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
plt.hist(sample, bins=15, density=True,  color='blue')
plt.plot(x,pdf, 'r-')
plt.plot(x,cdf, 'g-')
plt.show()
# Out:
# Sample mean: 1.0129884031707947
# Sample variance: 1.0425984855331907

# %% [markdown]
# d) Repeat (a) for an exponential random variable with $\lambda = 0.5$

# %%
#type your code here:
# Out:
# Sample mean: 1.9959330233482213
# Sample variance: 4.0065581143160705

# %%
#type your code here:
sample=stats.expon.rvs(scale=1/0.5, size=100000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)
pdf=stats.expon.pdf(x, scale=1/0.5)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
plt.hist(sample, bins=15, density=True,  color='blue')
plt.plot(x,pdf, 'r-')
plt.show()
# Out:
# Sample mean: 2.0025258279345755
# Sample variance: 3.956427741207947

# %%
#type your code here:

# %%
#my code
sample=stats.expon.rvs(scale=1/0.5, size=1000)
sample_mean = np.mean(sample)
sample_variance = np.var(sample)
pdf=stats.expon.pdf(x, scale=1/0.5)
cdf=stats.expon.cdf(x, scale=1/0.5)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
plt.hist(sample, bins=15, density=True,  color='blue')
plt.plot(x,pdf, 'r-')
plt.plot(x,cdf, 'g-')
plt.show()
# Out:
# Sample mean: 1.969223017914528
# Sample variance: 3.982354960494431

# %% [markdown]
# e) Repeat for an binomial random variable with $n = 5$ and $p = 0.5$

# %%
#type your code here:
# Out:
# Sample mean: 2.499239
# Sample variance: 1.2508546717336713

# %%
# my code
n = 5
p = 0.5

x=stats.binom.rvs(n=n,p=p, size=1000)
plt.hist(x,density=True,bins=np.arange(-0.5, n + 1.5, 1),color='b',label='Histogram')
sample_mean = np.mean(x)
sample_variance = np.var(x)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
x =np.arange(0,n+1)
y=stats.binom.pmf(x,n=n,p=p)
plt.bar(x,y,color='r',width=0.05,label='PMF')
plt.grid()
plt.legend()
# Out:
# Sample mean: 2.45
# Sample variance: 1.2135

# %%
#type your code here:

# %%
# my code
n = 5
p = 0.5

x =np.arange(0,n+1)
y=stats.binom.pmf(x,n=n,p=p)
plt.bar(x,y,color='r',width=0.05,label='PMF')


y=stats.binom.cdf(x,n=n,p=p)
plt.step(x,y,where='mid',color='b',label='CDF')
plt.legend()
plt.grid()

# %% [markdown]
# f) Repeat for an binomial random variable with $n = 20$ and $p = 0.5$

# %%
#type your code here:
# Out:
# Sample mean: 10.000802
# Sample variance: 4.998190354986355

# %%
# my code
n = 20
p = 0.5

x=stats.binom.rvs(n=n,p=p, size=100000)
plt.hist(x,density=True,bins=np.arange(-0.5, n + 1.5, 1),color='b',label='Histogram')
sample_mean = np.mean(x)
sample_variance = np.var(x)
print(f"Sample mean: {sample_mean}")
print(f"Sample variance: {sample_variance}")
x =np.arange(0,n+1)
y=stats.binom.pmf(x,n=n,p=p)
plt.bar(x,y,color='r',width=0.05,label='PMF')
plt.grid()
plt.legend()
# Out:
# Sample mean: 9.99002
# Sample variance: 5.0178403996

# %%
#type your code here:

# %%
# my code
n = 20
p = 0.5

x =np.arange(0,n+1)
y=stats.binom.pmf(x,n=n,p=p)
plt.bar(x,y,color='r',width=0.05,label='PMF')


y=stats.binom.cdf(x,n=n,p=p)
plt.step(x,y,where='mid',color='b',label='CDF')
plt.legend()
plt.grid()

# %% [markdown]
# # Problem 2
#
# (a) In this problem, you will use [seaborn](https://seaborn.pydata.org/) for statistical data visualization:
#
# - Load the penguins data `df = sns.load_dataset("penguins")`.
# - Display the first 5 rows of the dataset and use any relevant functions that can help you to understand the data.

# %%
df = sns.load_dataset("penguins")

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# - Use seaborn different plots to explore the data.
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
#type your code here:
sns.pairplot(df,diag_kind='kde')

# %% [markdown]
# - [heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) : `sns.heatmap(df.corr(), annot=True)`

# %%
#type your code here:

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
#type your code here:

# %%
sns.pairplot(df,diag_kind='kde',hue='species')

# %%
#type your code here:

# %%
sns.pairplot(df,diag_kind='kde',hue='sex')

# %%
#type your code here:

# %%
sns.pairplot(df,diag_kind='kde',hue='island')

# %% [markdown]
# - [displot](https://seaborn.pydata.org/generated/seaborn.displot.html)

# %%
#type your code here:

# %%
sns.displot(x=df['flipper_length_mm'],row=df['sex'],col=df['species'],kind='hist')

# %%
#type your code here:

# %%
sns.displot(x=df['flipper_length_mm'],row=df['sex'],col=df['island'],kind='hist')

# %%
#type your code here:

# %%
sns.displot(x=df['flipper_length_mm'],row=df['species'],col=df['island'],kind='hist')

# %% [markdown]
# - [jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)

# %%
#type your code here:

# %%
sns.jointplot(data=df, x="bill_depth_mm",y="bill_length_mm", hue="species", kind='scatter')

# %%
#type your code here:

# %%
sns.jointplot(data=df, x="bill_depth_mm",y="bill_length_mm",kind='hex')

# %% [markdown]
# - [swarmplot](https://seaborn.pydata.org/generated/seaborn.swarmplot.html)

# %%
#type your code here:
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='sex'>

# %%
sns.swarmplot(data=df,  x="body_mass_g", y="sex", hue="species")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='sex'>

# %% [markdown]
# - [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
#type your code here:
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(data=df,  x="species", y="body_mass_g",hue="species")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# #### Another interesting examples:
#
# - https://seaborn.pydata.org/examples/marginal_ticks.html
# - https://seaborn.pydata.org/examples/layered_bivariate_plot.html
# - https://seaborn.pydata.org/examples/joint_kde.html
# - https://seaborn.pydata.org/examples/joint_histogram.html
# - https://seaborn.pydata.org/examples/jitter_stripplot.html
# - https://seaborn.pydata.org/examples/horizontal_boxplot.html

# %% [markdown]
# (b) Exploring iris data:

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# # Problem 3: Practicing the Central Limit Theorem
# Use Python to simulate the Central Limit Theorem for the following random i.i.d variables and check that the higher the number of number the variables, the more the mean of subsets behave like a gaussian random variable.
